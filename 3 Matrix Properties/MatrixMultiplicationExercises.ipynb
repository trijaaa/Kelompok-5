# %% [markdown]
# no1

# %%
import torch

# %%
M_e = torch.tensor([[0, 1, 5], [2, 4, 3], [8, 2, 1]])
M_e
# Out:
# tensor([[0, 1, 5],
#         [2, 4, 3],
#         [8, 2, 1]])

# %%
V_e = torch.tensor([[-2, 1, -3], [0, -1, 2]]).T
V_e
# Out:
# tensor([[-2,  0],
#         [ 1, -1],
#         [-3,  2]])

# %%
torch.matmul(M_e, V_e)
# Out:
# tensor([[-14,   9],
#         [ -9,   2],
#         [-17,   0]])
